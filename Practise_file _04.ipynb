# %% [markdown]
# # Practise exercise 4

# %% [markdown]
# ## Background
#
#
# In the wake of the SARS-CoV-2 pandemic, causing COVID-19 disease, international air travel effectively stopped. With cases within many countries declining, understanding how to safely re-open international travel and to which countries is of key importance for the United Kingdom. In particular, it is imperative to determine a risk-based entry strategy, and for that strategy to be flexible in order to quickly react to changing disease prevalence.  Prevalence is defined as the total number of cases existing in a country’s population divided by the total country population worldwide.
#
# UK government researchers were tasked with estimating the weekly number of infectious travellers from 25 countries that have most flights to the UK. They modelled a country’s prevalence by taking the number of cases in the past 7 days, dividing it by an asymptomatic factor (0.5) and then dividing the result by the total population of each country.
#
# To implement their model, they turned to software developers to gather the relevant data, extract the key metrics per country and calculate the disease prevalence per week. This Notebook uses four sources of real data:
#
# 1. EUnonEUcombinedTravel.css : Travel Data provided by Dr Taylor, but freely available from Eurostat website. In the file there is a row for every airport-country combination with how many passengers are expected in 1 month from that country to that airport. It does not include the country's name, but only their ISO3 codes.
#
# 2. ISOcodes.csv: provided by Dr Taylor, this file has the ISO2, ISO3 and country names in it. It is necessary to  match this with the Travel Data to find out which countries the ISO3’s are referring to.
#
# 3. WorldPopData.csv : This is a database of all the world population per country obtained from https://worldpopulationreview.com/countries
#
# 4. WHOCOVID.csv : Database from the World Health Organization with information on the most recent COVID numbers per country, obtained from https://covid19.who.int/table
#
#
# This work is based on the paper: Taylor, R., McCarthy, C. A., Patel, V., Moir, R., Kelly, L., & Snary, E. (2020). The risk of introducing SARS-CoV-2 to the UK via international travel in August 2020. medRxiv.

# %% [markdown]
# ## Functions used throughout the code

# %%
#Function to extract info on CSV. Needs a csv file as input.
def extract_csv(filename):
    # importing csv module 
    import csv 
    # arrays to store data
    fields = [] #for top header, usually strings
    rows = [] #for actual data, mix of strings and numbers

    #read csv file
    # open simplifies exception handling and automatically closes the CSV file.
    with open(filename, "r") as csvfile:
        #create a csv reader object
        # maps the data into lists
        csvreader=csv.reader(csvfile)

        #extract field names through first row
        fields = next(csvreader)

        #extracting each data row one by one
        for row in csvreader:
            rows.append(row)
    
    d= dict();
    d["fields"]=fields
    d["data"]=rows
    return d #returns a dictionary with fields and data

# %%
#make dictionary to investigate which are the top 25 travelling countries
#input is travel_list[1]
def add_to_countries(rows):
    max_dictionary={}
    for row in rows:
        if str(row[2]) in max_dictionary.keys():
               max_dictionary[str(row[2])] = max_dictionary[str(row[2])] + int(row[4])
        else:
               max_dictionary.setdefault(str(row[2]), int(row[4]))
        # Used Lambda function, a function without a name, as a sorting mechanism 
        # allows us to sort our dictionary by value
        # reverse=True means that we want our data to be sorted in descending order
    return sorted(max_dictionary.items(), key = lambda x:x[1], reverse=True)

# %%
#make dictionary to investigate which are the top 25 UK airports
#input is travel_list[1]

def add_to_airports(rows):
    max_airports={}
    for row in rows:
        if str(row[1]) in max_airports.keys():
            max_airports[str(row[1])] = max_airports[str(row[1])] + int(row[4])
        else: 
            max_airports.setdefault(str(row[1]), int(row[4]))
            
        # Used Lambda function, a function without a name, as a sorting mechanism 
        # allows us to sort our dictionary by value
        # reverse = True means that we want our data to be sorted in descending order
    return sorted(max_airports.items(), key = lambda x:x[1], reverse = True)

# %%
#matches the top countries list to the country name
def matchData(list1,list2) :
    newList = []
    i = 0
    j = 0
    while i<len(list1) :
        while j<len(list2[1]) :
            if list1[i][0] == list2[1][j][2]:
                b=str(list1[i][0]),str((list2[1][j][0])),str(list1[i][1])
                newList.append(b)
            j= j+1
        i=i+1
        j=0
    return newList

# %%
#needs as input matchedCountries, who_covid_list, world_pop_list
def calculatePrevalence(list1, list2, list3) :

    newList = []
    i = 0
    j = 0
    k = 0
    while i<len(list1) :
        while j<len(list2[1]) :
            while k <len(list3[1]):                       
                if list1[i][1] == list2[1][j][0]:
                    if list2[1][j][0] == list3[1][k][1]:
                        #number of cases in last 7 days/ 0.5*total population*1000 because the CSV misinterprets data
                        prevalence = float(list2[1][j][4])/(0.5*float(list3[1][k][2])*1000)
                        b=str(list1[i][0]),str((list1[i][1])),str(prevalence)
                        newList.append(b)
                k= k + 1
            j= j + 1
            k=0
        i=i+1
        j=0        
    return newList

# %%
#sorting function for prevalence
def sortList(list1):
    def getKey(item):
        return item[2]
    return sorted(list1, key = getKey, reverse = True)

# %%
#needs as input the travel list and sorted Prevalence
def airportPrevalence (list1, list2):

    top_airports = []
    for i in list1[1] :
        for j in list2:
            #if country code matches with airport
            if j[0] == i[2]:
                b = float(i[4])*float(j[2])
                c = i[1], i[2], b
                top_airports.append(c)
    return top_airports

# %%
#Aggregate to get the total number of infected people arriving to each airport 
#input is airport_list

def airports_infected(rows):
    max_airports={ }
    for row in rows:
        if str(row[0]) in max_airports.keys():
            max_airports[str(row[0])] = max_airports[str(row[0])] + int(row[2])
        else: 
            max_airports.setdefault(str(row[0]), int(row[2]))
            
        # Used Lambda function, a function without a name, as a sorting mechanism 
        # allows us to sort our dictionary by value
        # reverse = True means that we want our data to be sorted in descending order
    return sorted(max_airports.items(), key = lambda x:x[1], reverse = True)

# %%
#number of infected people arriving from each country 
#input is airport_list

def countries_infected(rows):
    max_airports={ }
    for row in rows:
        if str(row[1]) in max_airports.keys():
            max_airports[str(row[1])] = max_airports[str(row[1])] + int(row[2])
        else: 
            max_airports.setdefault(str(row[1]), int(row[2]))
            
        # Used Lambda function, a function without a name, as a sorting mechanism 
        # allows us to sort our dictionary by value
        # reverse = True means that we want our data to be sorted in descending order
    return sorted(max_airports.items(), key = lambda x:x[1], reverse = True)

# %% [markdown]
# ## Research Questions
#
# 1. Which are the top 25 countries with COVID travelling by air into the UK?
#
# 2. Which are the top 25 UK airports people use to travel?
#
# 3. What is the disease prevalence to the top 25 countries travelling into the UK?
#
# 4. What is the number of infected people from the top 25 countries arriving at each UK airport?
#
# 5. a. What is the total number of infected people arriving to each airport? b. What is the total number of infected people arriving from each country in the top 25?

# %%
#1. Investigate which are the top 25 countries travelling into the UK
#make sure they include country code, country names and passengers 

# Get CSV data
# csv file name 
travelData = "EUnonEUcombinedTravel.csv" #provided by Dr Taylor
countryCode ="ISOcodes.csv"  #provided by Dr Taylor
worldPopData = "WorldPopData.csv" #obtained from https://worldpopulationreview.com/countries
whoCOVID = "WHOCOVID.csv" # obtained from https://covid19.who.int/table

#TIP: mac and pc have different ways of accessing a file

#Get dictionaries out of the data (keys:fields, values:data)
travel_dict = extract_csv(travelData)
world_pop_dict = extract_csv(worldPopData)
who_covid_dict = extract_csv(whoCOVID)
country_code_dict = extract_csv(countryCode)

#get lists of the data in dictionaries
travel_list = list(travel_dict.values())
world_pop_list = list(world_pop_dict.values())
who_covid_list = list(who_covid_dict.values())
country_code_list = list(country_code_dict.values())

#manipulate data
sorted_countries= add_to_countries(travel_list[1])
top_countries = sorted_countries [:25]
matchedCountries= matchData(top_countries,country_code_list)
matchedCountries
# Out:
# [('ESP', 'Spain', '2706321'),
#  ('USA', 'United States of America', '1124137'),
#  ('ITA', 'Italy', '864412'),
#  ('FRA', 'France', '746692'),
#  ('GRC', 'Greece', '723248'),
#  ('DEU', 'Germany', '651094'),
#  ('IRL', 'Ireland', '607160'),
#  ('PRT', 'Portugal', '531283'),
#  ('NLD', 'Netherlands', '468559'),
#  ('TUR', 'Turkey', '422079'),
#  ('POL', 'Poland', '383807'),
#  ('ARE', 'United Arab Emirates', '375013'),
#  ('CAN', 'Canada', '233581'),
#  ('CHE', 'Switzerland', '223895'),
#  ('CYP', 'Cyprus', '207526'),
#  ('HRV', 'Croatia', '175919'),
#  ('ROU', 'Romania', '172180'),
#  ('DNK', 'Denmark', '163288'),
#  ('BGR', 'Bulgaria', '140800'),
#  ('IND', 'India', '130743'),
#  ('HUN', 'Hungary', '124460'),
#  ('SWE', 'Sweden', '124270'),
#  ('QAT', 'Qatar', '119105'),
#  ('NOR', 'Norway', '113565'),
#  ('CZE', 'Czech Republic', '104123')]

# %%
#2. Investigate which are the top 25 UK airports people use to travel 
sorted_airports = add_to_airports(travel_list[1])
top_airports = sorted_airports [:25]
top_airports
# Out:
# [('LONDON HEATHROW airport', 3648223),
#  ('LONDON GATWICK airport', 2337904),
#  ('MANCHESTER airport', 1516365),
#  ('LONDON STANSTED airport', 1372224),
#  ('LONDON LUTON airport', 892184),
#  ('BIRMINGHAM airport', 641923),
#  ('EDINBURGH airport', 494420),
#  ('BRISTOL airport', 438491),
#  ('GLASGOW airport', 285216),
#  ('EAST MIDLANDS airport', 283101),
#  ('NEWCASTLE airport', 247822),
#  ('LEEDS BRADFORD airport', 238488),
#  ('LIVERPOOL airport', 218280),
#  ('LONDON/CITY airport', 184703),
#  ('BELFAST/ALDERGROVE airport', 156932),
#  ('SOUTHEND airport', 111425),
#  ('CARDIFF airport', 93162),
#  ('DONCASTER SHEFFIELD airport', 81437),
#  ('ABERDEEN/DYCE airport', 48726),
#  ('BOURNEMOUTH airport', 47806),
#  ('PRESTWICK airport', 41029),
#  ('SOUTHAMPTON airport', 37805),
#  ('EXETER airport', 35727),
#  ('NORWICH airport', 20162),
#  ('BELFAST/CITY airport', 11399)]

# %%
#3. Calculate the disease prevalence to the top 25 countries travelling into the UK. 
# Use sorted countries to get population, number of cases. prevalence = cases/(0.5*population)
# prevalence should be a number between 0 and 1.

prevalenceCountries = calculatePrevalence(matchedCountries, who_covid_list, world_pop_list)
sortedPrevalence = sortList(prevalenceCountries)
sortedPrevalence
# Out:
# [('IRL', 'Ireland', '0.01007860607972885'),
#  ('SWE', 'Sweden', '0.008164950617693467'),
#  ('PRT', 'Portugal', '0.007174275543216934'),
#  ('NLD', 'Netherlands', '0.006574545756746826'),
#  ('CYP', 'Cyprus', '0.006448786152254631'),
#  ('CHE', 'Switzerland', '0.005390183418755897'),
#  ('DNK', 'Denmark', '0.004948722437511675'),
#  ('HRV', 'Croatia', '0.0038194836048422672'),
#  ('ITA', 'Italy', '0.003775340824142493'),
#  ('POL', 'Poland', '0.0033476709446983244'),
#  ('FRA', 'France', '0.0032218582511977945'),
#  ('DEU', 'Germany', '0.0028994100086625193'),
#  ('CAN', 'Canada', '0.00277461641431488'),
#  ('ROU', 'Romania', '0.002622144206391505'),
#  ('HUN', 'Hungary', '0.0025309639370246486'),
#  ('ARE', 'United Arab Emirates', '0.0024933263582208286'),
#  ('TUR', 'Turkey', '0.0021703109426145298'),
#  ('BGR', 'Bulgaria', '0.001697933854265235'),
#  ('NOR', 'Norway', '0.0013491375867628833'),
#  ('QAT', 'Qatar', '0.0009885274585368614'),
#  ('GRC', 'Greece', '0.0008590572398454426'),
#  ('IND', 'India', '0.00018852114009768164'),
#  ('ESP', 'Spain', '0.0')]

# %%
#4.	Calculate the number of infected people arriving into each airport from top 25 countries
#by multiplying number of passengers from each country by prevalence in that country

airport_list = airportPrevalence(travel_list,sortedPrevalence)
infected_airports = sortList(airport_list)
infected_airports
# Out:
# [('LONDON HEATHROW airport', 'IRL', 1168.322095368248),
#  ('LONDON GATWICK airport', 'ITA', 894.6425150970465),
#  ('LONDON STANSTED airport', 'IRL', 791.8156080478175),
#  ('LONDON HEATHROW airport', 'DEU', 754.1104485630433),
#  ('LONDON GATWICK airport', 'IRL', 739.9107867372138),
#  ('LONDON GATWICK airport', 'PRT', 719.0848119721766),
#  ('LONDON STANSTED airport', 'ITA', 707.1326623843613),
#  ('MANCHESTER airport', 'IRL', 549.818197467448),
#  ('LONDON HEATHROW airport', 'CHE', 520.8588139378011),
#  ('LONDON GATWICK airport', 'FRA', 520.1819020888887),
#  ('LONDON STANSTED airport', 'PRT', 503.5193547251373),
#  ('BIRMINGHAM airport', 'IRL', 492.17864929747867),
#  ('LONDON HEATHROW airport', 'ITA', 479.0794245612099),
#  ('MANCHESTER airport', 'PRT', 475.5468543821345),
#  ('LONDON HEATHROW airport', 'FRA', 472.78192349726675),
#  ('LONDON HEATHROW airport', 'SWE', 451.2849855905356),
#  ('LONDON HEATHROW airport', 'NLD', 444.0250967734104),
#  ('LONDON HEATHROW airport', 'ARE', 443.5901857174258),
#  ('LONDON HEATHROW airport', 'PRT', 377.9408356166681),
#  ('LONDON HEATHROW airport', 'CAN', 365.3698132862263),
#  ('LONDON LUTON airport', 'IRL', 361.15677026100366),
#  ('EDINBURGH airport', 'IRL', 350.4633692104113),
#  ('LONDON STANSTED airport', 'FRA', 339.7127340062955),
#  ('LONDON LUTON airport', 'PRT', 325.0018563832703),
#  ('LONDON LUTON airport', 'POL', 322.71547906891846),
#  ('MANCHESTER airport', 'NLD', 318.90491647676157),
#  ('MANCHESTER airport', 'ITA', 309.62325166957413),
#  ('LONDON STANSTED airport', 'POL', 289.5367123360134),
#  ('LONDON STANSTED airport', 'DEU', 288.1172719708032),
#  ('LONDON GATWICK airport', 'NLD', 282.41618752681666),
#  ('LONDON LUTON airport', 'ROU', 268.7986247413996),
#  ('LONDON GATWICK airport', 'CYP', 262.96860171663934),
#  ('BRISTOL airport', 'IRL', 257.3168918215573),
#  ('MANCHESTER airport', 'DEU', 250.0886102971856),
#  ('GLASGOW airport', 'IRL', 248.91133435106343),
#  ('LIVERPOOL airport', 'IRL', 247.18789271142978),
#  ('LONDON HEATHROW airport', 'DNK', 227.57689873384942),
#  ('EDINBURGH airport', 'NLD', 225.62526128003756),
#  ('LONDON GATWICK airport', 'SWE', 221.87436808520226),
#  ('LONDON LUTON airport', 'NLD', 212.67998068500307),
#  ('MANCHESTER airport', 'CYP', 208.7794516792437),
#  ('MANCHESTER airport', 'FRA', 200.7024379001154),
#  ('LONDON STANSTED airport', 'NLD', 199.52431462575268),
#  ('LONDON LUTON airport', 'ITA', 198.50742053341227),
#  ('LONDON/CITY airport', 'NLD', 190.50403784749602),
#  ('LONDON GATWICK airport', 'HRV', 186.53594029328664),
#  ('LONDON/CITY airport', 'IRL', 185.72855283724326),
#  ('BIRMINGHAM airport', 'NLD', 185.42848852328748),
#  ('BRISTOL airport', 'PRT', 185.0532633617376),
#  ('LONDON GATWICK airport', 'CHE', 181.24491745566704),
#  ('LONDON GATWICK airport', 'TUR', 179.32411194446814),
#  ('LONDON LUTON airport', 'FRA', 172.47251590312032),
#  ('LONDON GATWICK airport', 'CAN', 171.7376575804338),
#  ('BIRMINGHAM airport', 'PRT', 170.0088075476117),
#  ('MANCHESTER airport', 'ARE', 169.90772468095835),
#  ('LONDON STANSTED airport', 'DNK', 168.08830631252155),
#  ('MANCHESTER airport', 'TUR', 167.70643746865255),
#  ('LONDON GATWICK airport', 'GRC', 159.44445994427355),
#  ('LONDON GATWICK airport', 'DNK', 149.8770077424786),
#  ('EAST MIDLANDS airport', 'PRT', 147.8115990168985),
#  ('EDINBURGH airport', 'DEU', 147.4060048404025),
#  ('LONDON STANSTED airport', 'SWE', 147.38552359998477),
#  ('BRISTOL airport', 'FRA', 146.57199742174126),
#  ('LONDON/CITY airport', 'CHE', 145.73438909290317),
#  ('BRISTOL airport', 'ITA', 145.112775257565),
#  ('LONDON LUTON airport', 'CYP', 142.7825741970698),
#  ('LEEDS BRADFORD airport', 'IRL', 138.62114802059062),
#  ('GLASGOW airport', 'NLD', 136.22458807979424),
#  ('EAST MIDLANDS airport', 'IRL', 135.7185094696287),
#  ('BRISTOL airport', 'NLD', 130.22860234964114),
#  ('BIRMINGHAM airport', 'DEU', 126.89267902911516),
#  ('LONDON STANSTED airport', 'TUR', 126.63981381250042),
#  ('EDINBURGH airport', 'ITA', 123.78587494198405),
#  ('LONDON STANSTED airport', 'CYP', 122.08197064833243),
#  ('EDINBURGH airport', 'FRA', 121.42217191289129),
#  ('LONDON GATWICK airport', 'ARE', 117.83709701587458),
#  ('LEEDS BRADFORD airport', 'PRT', 117.2635337538808),
#  ('LONDON HEATHROW airport', 'TUR', 116.2396837754916),
#  ('BELFAST/ALDERGROVE airport', 'PRT', 115.16864529526144),
#  ('MANCHESTER airport', 'GRC', 110.26171484864226),
#  ('LONDON GATWICK airport', 'DEU', 110.09059802891586),
#  ('BIRMINGHAM airport', 'CYP', 108.99738354540779),
#  ('LIVERPOOL airport', 'PRT', 106.73887153198154),
#  ('LONDON LUTON airport', 'CHE', 102.88782109721257),
#  ('EDINBURGH airport', 'PRT', 102.00384967345836),
#  ('NEWCASTLE airport', 'IRL', 101.36054134383305),
#  ('MANCHESTER airport', 'HRV', 100.29963946315793),
#  ('SOUTHEND airport', 'IRL', 100.11079418994667),
#  ('NEWCASTLE airport', 'NLD', 99.46630275382273),
#  ('MANCHESTER airport', 'DNK', 95.43611220741266),
#  ('LONDON HEATHROW airport', 'CYP', 94.35863897978976),
#  ('BIRMINGHAM airport', 'FRA', 93.44999857599203),
#  ('NEWCASTLE airport', 'PRT', 93.10057372432615),
#  ('ABERDEEN/DYCE airport', 'NLD', 92.45126243137386),
#  ('EDINBURGH airport', 'SWE', 91.58625107866762),
#  ('LONDON STANSTED airport', 'HRV', 91.23982435247208),
#  ('MANCHESTER airport', 'CHE', 90.33408391493008),
#  ('LONDON LUTON airport', 'HUN', 89.36833661634034),
#  ('LONDON HEATHROW airport', 'POL', 85.93806082135069),
#  ('BIRMINGHAM airport', 'ARE', 83.39428670341205),
#  ('SOUTHEND airport', 'PRT', 80.76799406553624),
#  ('BIRMINGHAM airport', 'ITA', 80.55067182390422),
#  ('MANCHESTER airport', 'SWE', 77.79564948538335),
#  ('LONDON/CITY airport', 'DEU', 77.64620003198226),
#  ('EDINBURGH airport', 'DNK', 76.14104342355463),
#  ('BIRMINGHAM airport', 'TUR', 72.3690183814815),
#  ('LONDON/CITY airport', 'ITA', 71.74280168117978),
#  ('LIVERPOOL airport', 'POL', 70.35800024472468),
#  ('BRISTOL airport', 'CYP', 70.30466663188),
#  ('SOUTHEND airport', 'NLD', 70.27531959386683),
#  ('LEEDS BRADFORD airport', 'NLD', 67.19843217970931),
#  ('LONDON HEATHROW airport', 'QAT', 66.96976973349675),
#  ('LIVERPOOL airport', 'NLD', 64.67380660911853),
#  ('LONDON/CITY airport', 'PRT', 64.3962972759152),
#  ('DONCASTER SHEFFIELD airport', 'POL', 63.5387945303742),
#  ('SOUTHAMPTON airport', 'IRL', 62.36641442136213),
#  ('GLASGOW airport', 'PRT', 60.084557674441825),
#  ('LONDON HEATHROW airport', 'GRC', 59.48112328689845),
#  ('BRISTOL airport', 'POL', 58.96587601991629),
#  ('LONDON LUTON airport', 'HRV', 58.94990995713555),
#  ('CARDIFF airport', 'IRL', 58.33497198947059),
#  ('EDINBURGH airport', 'POL', 57.85779693722114),
#  ('MANCHESTER airport', 'POL', 57.39247067590807),
#  ('LONDON STANSTED airport', 'GRC', 56.27082638159603),
#  ('EDINBURGH airport', 'CHE', 56.225003241042764),
#  ('LONDON LUTON airport', 'BGR', 56.00125438137598),
#  ('GLASGOW airport', 'ARE', 55.40919165874147),
#  ('LIVERPOOL airport', 'FRA', 54.30764268219002),
#  ('NEWCASTLE airport', 'CYP', 52.822007373117685),
#  ('BIRMINGHAM airport', 'POL', 52.5450431479849),
#  ('EAST MIDLANDS airport', 'CYP', 51.57739164573254),
#  ('LONDON HEATHROW airport', 'HUN', 51.22164815750484),
#  ('INVERNESS airport', 'NLD', 50.51880959484261),
#  ('LONDON GATWICK airport', 'NOR', 50.03816395544858),
#  ('NORWICH airport', 'NLD', 49.43400954497938),
#  ('MANCHESTER airport', 'CAN', 49.282736751060895),
#  ('LONDON STANSTED airport', 'HUN', 48.09843865921642),
#  ('LEEDS BRADFORD airport', 'CYP', 47.4759636528986),
#  ('BIRMINGHAM airport', 'GRC', 46.98441761886679),
#  ('EAST MIDLANDS airport', 'ITA', 46.73494406205992),
#  ('SOUTHAMPTON airport', 'NLD', 46.49518759171355),
#  ('LONDON HEATHROW airport', 'HRV', 46.269224389059225),
#  ('LONDON GATWICK airport', 'POL', 44.99604516769018),
#  ('LONDON HEATHROW airport', 'NOR', 44.729307551536635),
#  ('LIVERPOOL airport', 'ITA', 43.880786399008194),
#  ('LONDON LUTON airport', 'DEU', 43.380972549608614),
#  ('CARDIFF airport', 'NLD', 42.43869285980076),
#  ('SOUTHAMPTON airport', 'FRA', 41.874491690817734),
#  ('BRISTOL airport', 'HRV', 41.41466072730471),
#  ('GLASGOW airport', 'CAN', 41.08651986317474),
#  ('GLASGOW airport', 'CYP', 40.13724501163283),
#  ('BELFAST/ALDERGROVE airport', 'NLD', 40.06528184161516),
#  ('NEWCASTLE airport', 'TUR', 40.06394000066422),
#  ('LONDON GATWICK airport', 'HUN', 37.97964483899188),
#  ('HUMBERSIDE airport', 'NLD', 37.816787192807745),
#  ('EAST MIDLANDS airport', 'POL', 37.17923351181959),
#  ('BRISTOL airport', 'CHE', 37.06290118736555),
#  ('GLASGOW airport', 'DEU', 36.613749589390295),
#  ('BIRMINGHAM airport', 'CHE', 36.43763991078986),
#  ('LEEDS BRADFORD airport', 'POL', 36.3557064594238),
#  ('EDINBURGH airport', 'CYP', 36.274422106432304),
#  ('LONDON LUTON airport', 'TUR', 36.25504429637572),
#  ('LONDON HEATHROW airport', 'ROU', 35.55103115025602),
#  ('BRISTOL airport', 'TUR', 35.13082322810139),
#  ('SOUTHEND airport', 'FRA', 34.232243918976565),
#  ('MANCHESTER airport', 'BGR', 32.33035851906434),
#  ('LONDON GATWICK airport', 'ROU', 32.202552998694074),
#  ('BELFAST/ALDERGROVE airport', 'POL', 32.161074765716805),
#  ('BRISTOL airport', 'GRC', 32.15451248741492),
#  ('LEEDS BRADFORD airport', 'TUR', 30.032762823899862),
#  ('BELFAST/CITY airport', 'PRT', 30.009994597276435),
#  ('LONDON LUTON airport', 'GRC', 29.951889724451203),
#  ('BOURNEMOUTH airport', 'IRL', 29.741966541279837),
#  ('NEWCASTLE airport', 'FRA', 29.122376732576864),
#  ('LONDON STANSTED airport', 'ROU', 28.99304849007087),
#  ('GLASGOW airport', 'FRA', 28.825965773466667),
#  ('GLASGOW airport', 'ITA', 28.824727192327934),
#  ('CARDIFF airport', 'PRT', 28.496222457657662),
#  ('EAST MIDLANDS airport', 'GRC', 28.390982719652033),
#  ('PRESTWICK airport', 'PRT', 28.27381991581794),
#  ('BIRMINGHAM airport', 'HRV', 28.260359192227934),
#  ('NEWCASTLE airport', 'ARE', 28.226947701418002),
#  ('LONDON GATWICK airport', 'BGR', 28.219660657888205),
#  ('LEEDS BRADFORD airport', 'ITA', 28.209346637992706),
#  ('EAST MIDLANDS airport', 'FRA', 27.85940829810733),
#  ('LONDON STANSTED airport', 'BGR', 27.34522472294161),
#  ('DURHAM TEES VALLEY airport', 'NLD', 26.78469941298657),
#  ('NEWCASTLE airport', 'ITA', 26.616152810204575),
#  ('LIVERPOOL airport', 'CHE', 25.70578472404687),
#  ('LIVERPOOL airport', 'ROU', 25.589505310174697),
#  ('LEEDS BRADFORD airport', 'FRA', 25.552557790249708),
#  ('BELFAST/ALDERGROVE airport', 'FRA', 25.539670357244916),
#  ('LONDON STANSTED airport', 'ARE', 24.04065274596523),
#  ('EDINBURGH airport', 'TUR', 24.040534311341148),
#  ('DONCASTER SHEFFIELD airport', 'IRL', 23.876217802877648),
#  ('GLASGOW airport', 'POL', 23.75507302357931),
#  ('GLASGOW airport', 'TUR', 23.604301811875626),
#  ('ABERDEEN/DYCE airport', 'IRL', 23.594016832645238),
#  ('LONDON HEATHROW airport', 'IND', 23.478234266625176),
#  ('LONDON/CITY airport', 'FRA', 23.181270117368133),
#  ('LONDON LUTON airport', 'DNK', 22.917533608116567),
#  ('DONCASTER SHEFFIELD airport', 'ROU', 22.75758956727187),
#  ('SOUTHEND airport', 'ITA', 22.40287245046155),
#  ('BOURNEMOUTH airport', 'PRT', 22.082420122021723),
#  ('MANCHESTER airport', 'HUN', 22.07253649479196),
#  ('NEWQUAY airport', 'IRL', 21.638767253177843),
#  ('LONDON STANSTED airport', 'NOR', 21.595645351313472),
#  ('EXETER airport', 'IRL', 21.46743094982245),
#  ('EDINBURGH airport', 'HRV', 21.289801613390797),
#  ('CARDIFF airport', 'CYP', 21.1649161516997),
#  ('BELFAST/ALDERGROVE airport', 'ITA', 20.458571926028167),
#  ('BIRMINGHAM airport', 'ROU', 20.096113197784494),
#  ('EAST MIDLANDS airport', 'TUR', 19.76936237627575),
#  ('NEWCASTLE airport', 'GRC', 19.55300183612212),
#  ('BIRMINGHAM airport', 'DNK', 19.23073539217037),
#  ('BRISTOL airport', 'DEU', 18.776579216098476),
#  ('LIVERPOOL airport', 'CYP', 18.624094407711375),
#  ('LEEDS BRADFORD airport', 'GRC', 18.03161146435584),
#  ('DONCASTER SHEFFIELD airport', 'NLD', 17.94193537016209),
#  ('LEEDS BRADFORD airport', 'HRV', 17.92483655752476),
#  ('BELFAST/CITY airport', 'NLD', 17.87618991259462),
#  ('BIRMINGHAM airport', 'BGR', 17.714543901549195),
#  ('EXETER airport', 'NLD', 16.52840803246152),
#  ('DONCASTER SHEFFIELD airport', 'CYP', 16.102619022179816),
#  ('NEWCASTLE airport', 'POL', 16.06547286360726),
#  ('LONDON/CITY airport', 'POL', 15.821092884644282),
#  ('BOURNEMOUTH airport', 'CYP', 15.560920985390426),
#  ('EXETER airport', 'FRA', 15.261942535923952),
#  ('LONDON GATWICK airport', 'QAT', 15.226288443843275),
#  ('MANCHESTER airport', 'QAT', 15.221345806550591),
#  ('MANCHESTER airport', 'NOR', 15.129228897958974),
#  ('EAST MIDLANDS airport', 'NLD', 15.035986145679992),
#  ('LONDON HEATHROW airport', 'BGR', 14.710898913353995),
#  ('ABERDEEN/DYCE airport', 'DNK', 14.59378246822193),
#  ('EAST MIDLANDS airport', 'HRV', 14.426189575489243),
#  ('CARDIFF airport', 'ITA', 14.233034907017197),
#  ('GLASGOW airport', 'GRC', 12.852355365327668),
#  ('EXETER airport', 'PRT', 12.827604671271878),
#  ('DONCASTER SHEFFIELD airport', 'PRT', 12.770210466926143),
#  ('EDINBURGH airport', 'ARE', 12.623711351672055),
#  ('CARDIFF airport', 'FRA', 12.384823117604322),
#  ('CARDIFF airport', 'TUR', 12.336047397820987),
#  ('BELFAST/ALDERGROVE airport', 'HRV', 12.27963978956789),
#  ('EDINBURGH airport', 'CAN', 12.24160761995725),
#  ('ABERDEEN/DYCE airport', 'FRA', 12.178624189527664),
#  ('SOUTHEND airport', 'HRV', 11.901510912688504),
#  ('EDINBURGH airport', 'GRC', 11.846399337468654),
#  ('BELFAST/ALDERGROVE airport', 'CYP', 11.762585941712448),
#  ('PRESTWICK airport', 'ITA', 11.51101417281046),
#  ('ABERDEEN/DYCE airport', 'PRT', 11.450143766974227),
#  ('NEWQUAY airport', 'PRT', 11.356878184912407),
#  ('LONDON LUTON airport', 'SWE', 11.18598234624005),
#  ('BRISTOL airport', 'DNK', 10.946574031775826),
#  ('BRISTOL airport', 'SWE', 10.916538975856165),
#  ('EXETER airport', 'CYP', 10.866204666549054),
#  ('GLASGOW airport', 'HRV', 10.835874986937512),
#  ('SOUTHAMPTON airport', 'PRT', 10.81163324362792),
#  ('ABERDEEN/DYCE airport', 'NOR', 10.62176022058418),
#  ('NEWCASTLE airport', 'HRV', 10.369897987146755),
#  ('DONCASTER SHEFFIELD airport', 'HUN', 10.356704430304863),
#  ('LONDON/CITY airport', 'HUN', 10.354173466367838),
#  ('EDINBURGH airport', 'HUN', 10.174475026839087),
#  ('BELFAST/ALDERGROVE airport', 'TUR', 10.022495932993898),
#  ('INVERNESS airport', 'IRL', 9.685540442619425),
#  ('EAST MIDLANDS airport', 'HUN', 9.486052835968383),
#  ('CARDIFF airport', 'GRC', 8.932477179912913),
#  ('SOUTHEND airport', 'DNK', 8.8582131631459),
#  ('EDINBURGH airport', 'NOR', 8.728920186355856),
#  ('NEWCASTLE airport', 'CHE', 8.68358548761575),
#  ('ABERDEEN/DYCE airport', 'POL', 8.429435438750382),
#  ('LONDON STANSTED airport', 'CAN', 8.379341571230936),
#  ('EDINBURGH airport', 'QAT', 7.928978744924165),
#  ('NEWCASTLE airport', 'BGR', 7.774839118680511),
#  ('LIVERPOOL airport', 'DEU', 7.732726493102939),
#  ('DONCASTER SHEFFIELD airport', 'FRA', 7.413495836006125),
#  ('GLASGOW airport', 'ROU', 7.1453429624168505),
#  ('EDINBURGH airport', 'BGR', 7.104155246245743),
#  ('DONCASTER SHEFFIELD airport', 'HRV', 7.016391382095245),
#  ('EAST MIDLANDS airport', 'BGR', 6.767964343101227),
#  ('LIVERPOOL airport', 'TUR', 6.719282678334584),
#  ('LIVERPOOL airport', 'BGR', 6.633827568614273),
#  ('LIVERPOOL airport', 'DNK', 6.49767256045283),
#  ('BRISTOL airport', 'HUN', 6.479267678783101),
#  ('BIRMINGHAM airport', 'QAT', 6.474854853416442),
#  ('LIVERPOOL airport', 'HUN', 6.175552006340142),
#  ('BRISTOL airport', 'BGR', 6.175385427962659),
#  ('BIRMINGHAM airport', 'HUN', 6.023694170118664),
#  ('SOUTHEND airport', 'ROU', 6.012576665255721),
#  ('CARDIFF airport', 'QAT', 5.917325366801652),
#  ('DONCASTER SHEFFIELD airport', 'GRC', 5.769428422801993),
#  ('PRESTWICK airport', 'POL', 5.727864986378833),
#  ('NORWICH airport', 'CYP', 5.649136669375057),
#  ('BELFAST/ALDERGROVE airport', 'BGR', 5.594692049803949),
#  ('BOURNEMOUTH airport', 'POL', 5.520309387807537),
#  ('EXETER airport', 'ITA', 5.243948404733922),
#  ('DONCASTER SHEFFIELD airport', 'TUR', 5.206575951332257),
#  ('GLASGOW airport', 'BGR', 5.063238753418931),
#  ('LEEDS BRADFORD airport', 'DEU', 4.946393474778258),
#  ('LONDON/CITY airport', 'HRV', 4.720881735585042),
#  ('BELFAST/ALDERGROVE airport', 'DEU', 4.688345984007293),
#  ('EAST MIDLANDS airport', 'DEU', 4.491186103418243),
#  ('DONCASTER SHEFFIELD airport', 'BGR', 4.382367277858571),
#  ('NEWCASTLE airport', 'DEU', 4.343316192976454),
#  ('BRISTOL airport', 'ROU', 4.334404373165158),
#  ('LIVERPOOL airport', 'HRV', 4.31219698986692),
#  ('LEEDS BRADFORD airport', 'BGR', 4.2940747174367795),
#  ('GLASGOW airport', 'HUN', 4.064728082861586),
#  ('LIVERPOOL airport', 'GRC', 3.9791531349640903),
#  ('SOUTHAMPTON airport', 'DEU', 3.862014131538476),
#  ('LONDON/CITY airport', 'GRC', 3.784147141519175),
#  ('EXETER airport', 'TUR', 3.36832258293775),
#  ('BELFAST/ALDERGROVE airport', 'GRC', 3.3580547505558354),
#  ('NORWICH airport', 'TUR', 3.2749992124053255),
#  ('LONDON/CITY airport', 'DNK', 3.2661568087577058),
#  ('CARDIFF airport', 'HRV', 3.242741580511085),
#  ('LEEDS BRADFORD airport', 'HUN', 3.148519137658663),
#  ('BOURNEMOUTH airport', 'GRC', 3.0015459960199764),
#  ('DONCASTER SHEFFIELD airport', 'ITA', 2.8617083447000096),
#  ('EXETER airport', 'GRC', 2.660500271801336),
#  ('HUMBERSIDE airport', 'BGR', 2.4908689642071),
#  ('CARDIFF airport', 'BGR', 2.4093681392023685),
#  ('SOUTHAMPTON airport', 'ITA', 2.295407221078636),
#  ('NEWQUAY airport', 'DNK', 2.276412321255371),
#  ('CARDIFF airport', 'DEU', 2.2035516065835146),
#  ('NEWQUAY airport', 'DEU', 2.1687586864795643),
#  ('ABERDEEN/DYCE airport', 'TUR', 1.998856378147982),
#  ('NORWICH airport', 'GRC', 1.9715363654452909),
#  ('BOURNEMOUTH airport', 'TUR', 1.9402579826973896),
#  ('GLASGOW airport', 'SWE', 1.8861035926871907),
#  ('INVERNESS airport', 'CHE', 1.6601764929768164),
#  ('DURHAM TEES VALLEY airport', 'BGR', 1.4517334453967758),
#  ('GLASGOW airport', 'DNK', 1.4499756741909209),
#  ('ABERDEEN/DYCE airport', 'BGR', 1.409285099040145),
#  ('ABERDEEN/DYCE airport', 'GRC', 1.3994042437082261),
#  ('SOUTHEND airport', 'GRC', 1.2318880819383649),
#  ('NORWICH airport', 'BGR', 1.1953454334027254),
#  ('BIRMINGHAM airport', 'IND', 1.1695851531660169),
#  ('BELFAST/ALDERGROVE airport', 'DNK', 0.9105649285021482),
#  ('NEWCASTLE airport', 'NOR', 0.7946420386033383),
#  ('BELFAST/ALDERGROVE airport', 'SWE', 0.7430105062101054),
#  ('ABERDEEN/DYCE airport', 'HRV', 0.6302147947989741),
#  ('PRESTWICK airport', 'FRA', 0.6024874929739876),
#  ('INVERNESS airport', 'NOR', 0.5882239878286172),
#  ('GLASGOW airport', 'NOR', 0.38990076257447326),
#  ('LIVERPOOL airport', 'NOR', 0.30220681943488586),
#  ('SOUTHEND airport', 'DEU', 0.22905339068433903),
#  ('SUMBURGH airport', 'NOR', 0.21451287629529844),
#  ('NORWICH airport', 'FRA', 0.10309946403832942),
#  ('KIRKWALL airport', 'NOR', 0.07420256727195858),
#  ('DUNDEE airport', 'NOR', 0.0080948255205773),
#  ('BELFAST/ALDERGROVE airport', 'ESP', 0.0),
#  ('BELFAST/CITY airport', 'ESP', 0.0),
#  ('BIRMINGHAM airport', 'ESP', 0.0),
#  ('MANCHESTER airport', 'ESP', 0.0),
#  ('DONCASTER SHEFFIELD airport', 'ESP', 0.0),
#  ('CARDIFF airport', 'ESP', 0.0),
#  ('BRISTOL airport', 'ESP', 0.0),
#  ('LIVERPOOL airport', 'ESP', 0.0),
#  ('LONDON LUTON airport', 'ESP', 0.0),
#  ('BOURNEMOUTH airport', 'ESP', 0.0),
#  ('SOUTHAMPTON airport', 'ESP', 0.0),
#  ('NEWQUAY airport', 'ESP', 0.0),
#  ('LONDON GATWICK airport', 'ESP', 0.0),
#  ('LONDON/CITY airport', 'ESP', 0.0),
#  ('LONDON HEATHROW airport', 'ESP', 0.0),
#  ('SOUTHEND airport', 'ESP', 0.0),
#  ('HUMBERSIDE airport', 'ESP', 0.0),
#  ('LEEDS BRADFORD airport', 'ESP', 0.0),
#  ('NEWCASTLE airport', 'ESP', 0.0),
#  ('EAST MIDLANDS airport', 'DNK', 0.0),
#  ('EAST MIDLANDS airport', 'ESP', 0.0),
#  ('ABERDEEN/DYCE airport', 'ESP', 0.0),
#  ('GLASGOW airport', 'ESP', 0.0),
#  ('EDINBURGH airport', 'ESP', 0.0),
#  ('PRESTWICK airport', 'ESP', 0.0),
#  ('NORWICH airport', 'ESP', 0.0),
#  ('LONDON STANSTED airport', 'ESP', 0.0),
#  ('EXETER airport', 'ESP', 0.0),
#  ('BOURNEMOUTH airport', 'NOR', 0.0),
#  ('EAST MIDLANDS airport', 'NOR', 0.0),
#  ('STORNOWAY airport', 'NOR', 0.0),
#  ('LONDON STANSTED airport', 'QAT', 0.0)]

# %%
#5.a.Aggregate to get the total number of infected people arriving from the 
# top 25 countries arriving at each UK airport

infected_arriving = airports_infected(infected_airports)
infected_arriving
# Out:
# [('LONDON HEATHROW airport', 6333),
#  ('LONDON GATWICK airport', 5095),
#  ('LONDON STANSTED airport', 3982),
#  ('MANCHESTER airport', 3307),
#  ('LONDON LUTON airport', 2446),
#  ('BIRMINGHAM airport', 1640),
#  ('EDINBURGH airport', 1496),
#  ('BRISTOL airport', 1190),
#  ('LONDON/CITY airport', 790),
#  ('GLASGOW airport', 758),
#  ('LIVERPOOL airport', 690),
#  ('EAST MIDLANDS airport', 538),
#  ('LEEDS BRADFORD airport', 534),
#  ('NEWCASTLE airport', 532),
#  ('SOUTHEND airport', 332),
#  ('BELFAST/ALDERGROVE airport', 277),
#  ('CARDIFF airport', 207),
#  ('DONCASTER SHEFFIELD airport', 193),
#  ('ABERDEEN/DYCE airport', 173),
#  ('SOUTHAMPTON airport', 164),
#  ('EXETER airport', 84),
#  ('BOURNEMOUTH airport', 75),
#  ('INVERNESS airport', 60),
#  ('NORWICH airport', 59),
#  ('BELFAST/CITY airport', 47),
#  ('PRESTWICK airport', 44),
#  ('HUMBERSIDE airport', 39),
#  ('NEWQUAY airport', 36),
#  ('DURHAM TEES VALLEY airport', 27),
#  ('SUMBURGH airport', 0),
#  ('KIRKWALL airport', 0),
#  ('DUNDEE airport', 0),
#  ('STORNOWAY airport', 0)]

# %%
#5.b. Calculate the number of infected people arriving from each top 25 countries 

country_arriving = countries_infected(airport_list)
matchedArrivals= matchData(country_arriving, country_code_list)
matchedArrivals
# Out:
# [('IRL', 'Ireland', '6107'),
#  ('PRT', 'Portugal', '3802'),
#  ('ITA', 'Italy', '3253'),
#  ('NLD', 'Netherlands', '3068'),
#  ('FRA', 'France', '2395'),
#  ('DEU', 'Germany', '1879'),
#  ('CYP', 'Cyprus', '1328'),
#  ('POL', 'Poland', '1274'),
#  ('CHE', 'Switzerland', '1201'),
#  ('SWE', 'Sweden', '1009'),
#  ('ARE', 'United Arab Emirates', '931'),
#  ('TUR', 'Turkey', '908'),
#  ('DNK', 'Denmark', '800'),
#  ('HRV', 'Croatia', '663'),
#  ('CAN', 'Canada', '646'),
#  ('GRC', 'Greece', '609'),
#  ('ROU', 'Romania', '447'),
#  ('HUN', 'Hungary', '311'),
#  ('BGR', 'Bulgaria', '231'),
#  ('NOR', 'Norway', '148'),
#  ('QAT', 'Qatar', '114'),
#  ('IND', 'India', '24'),
#  ('ESP', 'Spain', '0')]
